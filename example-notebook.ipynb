# %%
foo = 7

# %%
bar = 42

# %%
print "Sum:", foo + bar
print "Product:", foo * bar
# Out:
# Sum: 49
# Product: 294

# %%
print "Hello, world!"
# Out:
# Hello, world!

# %%
import browsercast
browsercast.load(browsercast_js="url:files/browsercast.js", browsercast_css="url:files/browsercast.css")
# Out:
# <p class='bc-loading-status-output'>Loading BrowserCast&hellip;</p>
# ...
